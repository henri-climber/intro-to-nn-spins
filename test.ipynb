# %%
import pandas as pd

df = pd.read_csv('NitratprojektHessen.csv')
df.head()
# Out:
#         Id        Creation Time    Owner  \
# 0  NIT-103  2025-01-25 14:59:07  henri-b
# 1  NIT-102  2025-01-25 14:53:27  henri-b
# 2  NIT-101  2025-01-25 14:47:51  henri-b
# 3  NIT-100  2025-01-25 14:41:57  henri-b
# 4   NIT-99  2025-01-25 14:35:42  henri-b
#
#                                                 Name  \
# 0  Encoding: False, Source: 3x3, FeatureSel: Fals...
# 1  Encoding: False, Source: 3x3, FeatureSel: True...
# 2  Encoding: False, Source: 3x3, FeatureSel: True...
# 3  Encoding: False, Source: 3x3, FeatureSel: True...
# 4  Encoding: False, Source: 3x3, FeatureSel: True...
#
#                                                 Tags Group Tags  \
# 0  ["with computed NO3","dependent_variable_P_GES...         []
# 1  ["num_features_20","with computed NO3","depend...         []
# 2  ["num_features_15","with computed NO3","depend...         []
# 3  ["with computed NO3","dependent_variable_P_GES...         []
# 4  ["with computed NO3","dependent_variable_P_GES...         []
#
# ...

# %%
df.to_excel("Nitrat.xlsx")
